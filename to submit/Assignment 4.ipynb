# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/Users/christopherbarnes/cmsc25910/Assignment4/data.csv')
data_full = pd.read_csv('/Users/christopherbarnes/cmsc25910/Assignment4/data-full.csv')

# %%
print(data)
# Out:
#        reviewid                                              title  \
# 0             1                                      young forever
# 1             6                               pure tone audiometry
# 2             7  or you could just go through your whole life a...
# 3             8                                     bleeding light
# 4            10                                               abcs
# ...         ...                                                ...
# 18388     22721                                       prelapsarian
# 18389     22722      insecure (music from the hbo original series)
# 18390     22724                       filthy america its beautiful
# 18391     22725                                          new start
# 18392     22745                                   run the jewels 3
#
#                 artist                                                url  \
# 0            aberfeldy  http://pitchfork.com/reviews/albums/1-young-fo...
# ...

# %%
print(data_full)
# Out:
#        reviewid                                              title  \
# 0             1                                      young forever
# 1             6                               pure tone audiometry
# 2             7  or you could just go through your whole life a...
# 3             8                                     bleeding light
# 4            10                                               abcs
# ...         ...                                                ...
# 18388     22721                                       prelapsarian
# 18389     22722      insecure (music from the hbo original series)
# 18390     22724                       filthy america its beautiful
# 18391     22725                                          new start
# 18392     22745                                   run the jewels 3
#
#                 artist                                                url  \
# 0            aberfeldy  http://pitchfork.com/reviews/albums/1-young-fo...
# ...

# %%
#working to find trends between data and data_full

# %%
#drop na values from data
score_nulls = data[data['score'].isnull()]
title_nulls = data[data['title'].isnull()]
author_type_nulls = data[data['author_type'].isnull()]

print('scores dataframe size ' + str(len(score_nulls)))
print('title dataframe size ' + str(len(title_nulls)))
print('author_type dataframe size ' + str(len(author_type_nulls)))
print('dataframe size ' + str(len(data)))
print('dataframe full size ' + str(len(data_full)))
# Out:
# scores dataframe size 357
# title dataframe size 58
# author_type dataframe size 3906
# dataframe size 18393
# dataframe full size 18393

# %%
#finding the values that are in data_full but NOT data, comparing the two documents
def compare_data(df):
    reviewids = df['reviewid']
    df_temp = pd.DataFrame() 
    df_out = data_full.loc[data_full['reviewid'].isin(reviewids)]
    return df_out

scores_compare = pd.DataFrame()
author_type_compare = pd.DataFrame()
title_compare = pd.DataFrame()


scores_compare = compare_data(score_nulls)
author_type_compare = compare_data(author_type_nulls)
title_compare = compare_data(title_nulls)

#print(scores_compare)
#print(author_type_compare)
#print(title_compare)

# %%
display(scores_compare)
# Out:
#        reviewid                                              title  \
# 58           97                            rescue through tomahawk
# 167         281                                            everest
# 205         346                                  god save the abpk
# 313         486                            amusement parks on fire
# 341         527                             have you fed the fish?
# ...         ...                                                ...
# 18256     22579                                                xxx
# 18300     22628                                  patterns of light
# 18313     22641                                     love and noir.
# 18337     22665  punk45: les punks: the french connection (the ...
# 18359     22687                                skin companion ep i
#
#                         artist  \
# 58                     alaska!
# 167                  arcwelder
# 205        atombombpocketknife
# ...

# %%
display(title_compare)
# Out:
#        reviewid                                  title  \
# 336         520                  the process of belief
# 1318       2092         rough trade counter culture 05
# 1395       2226   you can play these songs with chords
# 1564       2527                             backstroke
# 1722       2734                danger! high voltage ep
# 1993       3199                            eph reissue
# 2231       3599          half smiles of the decomposed
# 2356       3782             we are amateurs, you and i
# 2622       4213                                   etc.
# 2945       4740      tell balgeary, balgury is dead ep
# 3358       5429                        under rug swept
# 3565       5693                                 let go
# 3737       5953                      aldhils arboretum
# 3802       6072                                   owen
# 3899       6216                          achilles heel
# 3900       6222                                enemies
# ...

# %%
display(author_type_compare)
# Out:
#        reviewid                                              title  \
# 2             7  or you could just go through your whole life a...
# 3             8                                     bleeding light
# 4            10                                               abcs
# 6            12                                            abilene
# 9            17                                  accepted eclectic
# ...         ...                                                ...
# 18264     22588                                black america again
# 18269     22595                                    l.a. heartbreak
# 18274     22600                                            arrival
# 18291     22619                                         flasher ep
# 18314     22642                                        im your man
#
#                artist                                                url  \
# 2            aarktica  http://pitchfork.com/reviews/albums/7-or-you-c...
# ...

# %%
#doing data vs data frame
#finding counts of na for each DF
score_dict = dict()
title_dict = dict()
author_type_dict = dict()

def na_counts(df, output):
    title = dict()
    artist = dict()
    score = dict()
    author = dict()
    pub_date = dict()
    
    ind = 0
    
    reviewids = df['reviewid']
    
    #print(reviewids)
    
    for ind in df.index:
    #while ind < len(df):
        #print(df['title'][ind])
        temp_title = df['title'][ind]
        temp_artist = df['artist'][ind]
        temp_score = df['score'][ind]
        temp_author = df['author'][ind]
        temp_pub_date = df['pub_date'][ind]
        
        #if else TITLE
        if temp_title in title:
            temp = title[temp_title]
            title[temp_title] = temp + 1
        else:
            title[temp_title] = 1
            
        #if else ARTIST
        if temp_artist in artist:
            temp = artist[temp_artist]
            artist[temp_artist] = temp + 1
        else:
            artist[temp_artist] = 1
            
        #if else SCORE
        if temp_score in score:
            temp = score[temp_score]
            score[temp_score] = temp + 1
        else:
            score[temp_score] = 1
            
        #if else AUTHOR
        if temp_author in author:
            temp = author[temp_author]
            author[temp_author] = temp + 1
        else:
            author[temp_author] = 1
            
        #if else PUB_DATE
        if temp_pub_date in pub_date:
            temp = pub_date[temp_pub_date]
            pub_date[temp_pub_date] = temp + 1
        else:
            pub_date[temp_pub_date] = 1   
    output['title'] = title
    output['score'] = score
    output['artist'] = artist
    output['author'] = author
    output['pub_date'] = pub_date
    
    #return output


na_counts(title_compare, title_dict)
na_counts(scores_compare, score_dict)
na_counts(author_type_compare, author_type_dict)

#type of dict represents what is null in those senarios

#print(title_dict)
#print(score_dict)
#print(author_type_dict)

# %%
#analyzing various outputs for title_dict()
print("titles where titles are NA:")
print(title_dict['title'])
# Out:
# titles where titles are NA:
# ...

# %%
print("scores where titles are NA:")
print(title_dict['score'])
# Out:
# scores where titles are NA:
# {5.1: 2, 7.2: 4, 6.4: 3, 6.8: 4, 7.8: 4, 7.0: 6, 8.2: 1, 4.2: 1, 8.4: 3, 3.8: 1, 6.1: 1, 4.7: 1, 6.3: 1, 4.4: 1, 4.8: 2, 9.0: 1, 6.0: 1, 5.4: 1, 0.4: 1, 6.6: 1, 4.6: 1, 8.7: 2, 8.1: 1, 5.2: 1, 8.0: 2, 4.9: 1, 6.2: 2, 8.3: 1, 10.0: 1, 6.7: 1, 4.5: 1, 7.9: 1, 5.5: 1, 5.7: 1, 5.0: 1}

# %%
print("authors where titles are NA:")
print(title_dict['author'])
# Out:
# authors where titles are NA:
# {'rob mitchum': 38, 'nick sylvester': 1, 'brad haywood': 1, 'zach baron': 1, 'jess harvell': 1, 'aaron leitko': 2, 'andrew gaerig': 1, 'nate patrin': 1, 'stuart berman': 1, 'joshua love': 1, 'matthew perpetua': 1, 'eric grandy': 2, 'brian howe': 1, 'ian cohen': 1, 'sheldon pearce': 1, 'marc masters': 1, 'philip sherburne': 1, 'jia tolentino': 1, 'zoe camp': 1}
# 58

# %%
print("pub_dates where titles are NA:")
print(title_dict['pub_date'])
# Out:
# pub_dates where titles are NA:
# ...

# %%
print("titles where scores are NA:")
print(score_dict['title'])
# Out:
# titles where scores are NA:
# ...

# %%
print("scores where scores are NA:")
print(score_dict['score'])
# Out:
# scores where scores are NA:
# {6.6: 343, 5.7: 1, 8.0: 1, 3.3: 1, 7.6: 1, 0.4: 1, 8.3: 1, 6.1: 1, 6.9: 1, 4.9: 1, 7.0: 1, 7.2: 1, 7.7: 1, 7.3: 1, 9.1: 1}

# %%
print("artists where scores are NA:")
print(score_dict['artist'])
# Out:
# artists where scores are NA:
# ...

# %%
print("authors where scores are NA:")
print(score_dict['author'])
# Out:
# authors where scores are NA:
# ...

# %%
print("pub_dates where scores are NA:")
print(score_dict['pub_date'])
# Out:
# pub_dates where scores are NA:
# ...

# %%
print("titles where author types are NA:")
print(author_type_dict['title'])
# Out:
# titles where author types are NA:
# ...

# %%
print("scores where author types are NA:")
print(author_type_dict['score'])
# Out:
# scores where author types are NA:
# {8.1: 76, 7.2: 153, 8.0: 155, 7.0: 221, 7.3: 133, 8.9: 21, 8.2: 85, 9.0: 29, 5.5: 44, 3.1: 7, 4.6: 13, 6.8: 133, 6.5: 97, 7.6: 128, 2.8: 7, 7.5: 183, 7.9: 116, 7.4: 147, 5.0: 42, 3.2: 4, 5.9: 60, 4.5: 24, 6.9: 123, 6.7: 93, 4.4: 19, 4.8: 27, 2.6: 8, 8.6: 46, 7.7: 127, 7.8: 151, 2.0: 11, 6.0: 87, 4.3: 13, 9.4: 13, 8.4: 67, 3.8: 16, 7.1: 119, 3.6: 7, 6.2: 65, 8.7: 38, 3.5: 13, 6.1: 60, 3.0: 18, 8.3: 80, 5.7: 40, 6.6: 76, 2.7: 10, 1.7: 3, 5.1: 25, 6.4: 89, 4.9: 32, 6.3: 66, 5.8: 57, 8.5: 73, 2.9: 10, 4.0: 17, 3.3: 12, 5.2: 35, 9.3: 12, 2.4: 4, 5.4: 31, 5.6: 29, 9.7: 5, 2.5: 5, 5.3: 30, 9.2: 9, 9.5: 13, 4.1: 16, 3.9: 11, 2.3: 4, 2.1: 4, 3.7: 11, 8.8: 12, 10.0: 8, 4.2: 10, 3.4: 10, 9.1: 10, 2.2: 2, 4.7: 20, 9.6: 5, 1.0: 2, 1.9: 3, 1.2: 1, 0.6: 1, 1.1: 1, 0.0: 1, 0.4: 1, 1.5: 5, 0.8: 2, 0.3: 1, 0.1: 1, 0.2: 1, 1.8: 1}

# %%
print("artists where author types are NA:")
print(author_type_dict['artist'])
# Out:
# artists where author types are NA:
# ...

# %%
print("authors where author types are NA:")
print(author_type_dict['author'])
# Out:
# authors where author types are NA:
# ...

# %%
print("pub_dates where author types are NA:")
print(author_type_dict['pub_date'])
# Out:
# pub_dates where author types are NA:
# ...

# %%
#finding counts of na for each DF
score_data_dict = dict()
title_data_dict = dict()
author_type_data_dict = dict()

def data_na_counts(df, output):
    title = dict()
    artist = dict()
    score = dict()
    author = dict()
    pub_date = dict()
    
    ind = 0
    
    reviewids = df['reviewid']
    
    #print(reviewids)
    
    for ind in df.index:
    #while ind < len(df):
        #print(df['title'][ind])
        temp_title = df['title'][ind]
        temp_artist = df['artist'][ind]
        temp_score = df['score'][ind]
        temp_author = df['author'][ind]
        temp_pub_date = df['pub_date'][ind]
        
        #if else TITLE
        if temp_title in title:
            temp = title[temp_title]
            title[temp_title] = temp + 1
        else:
            title[temp_title] = 1
            
        #if else ARTIST
        if temp_artist in artist:
            temp = artist[temp_artist]
            artist[temp_artist] = temp + 1
        else:
            artist[temp_artist] = 1
            
        #if else SCORE
        if temp_score in score:
            temp = score[temp_score]
            score[temp_score] = temp + 1
        else:
            score[temp_score] = 1
            
        #if else AUTHOR
        if temp_author in author:
            temp = author[temp_author]
            author[temp_author] = temp + 1
        else:
            author[temp_author] = 1
            
        #if else PUB_DATE
        if temp_pub_date in pub_date:
            temp = pub_date[temp_pub_date]
            pub_date[temp_pub_date] = temp + 1
        else:
            pub_date[temp_pub_date] = 1   
    output['title'] = title
    output['score'] = score
    output['artist'] = artist
    output['author'] = author
    output['pub_date'] = pub_date
    
    #return output


#na_counts(title_compare, title_dict)
#na_counts(scores_compare, score_dict)
#na_counts(author_type_compare, author_type_dict)


data_na_counts(title_nulls, title_data_dict)
data_na_counts(score_nulls, score_data_dict)
data_na_counts(author_type_nulls, author_type_data_dict)

# %%
print("titles where scores are NA:")
print(score_data_dict['title'])
# Out:
# titles where scores are NA:
# ...

# %%
print("scores where scores are NA:")
print(score_data_dict['score'])
# Out:
# scores where scores are NA:
# ...

# %%
print("authors where scores are NA:")
print(score_data_dict['author'])
# Out:
# authors where scores are NA:
# ...

# %%
print("pub_dates where scores are NA:")
print(score_data_dict['pub_date'])
# Out:
# pub_dates where scores are NA:
# ...

# %%
print("titles where titles are NA:")
print(title_data_dict['title'])
# Out:
# titles where titles are NA:
# {nan: 58}

# %%
print("scores where titles are NA:")
print(title_data_dict['score'])
# Out:
# scores where titles are NA:
# {5.1: 2, 7.2: 4, 6.4: 3, 6.8: 4, 7.8: 4, 7.0: 6, 8.2: 1, 4.2: 1, 8.4: 3, 3.8: 1, 6.1: 1, 4.7: 1, 6.3: 1, 4.4: 1, 4.8: 2, 9.0: 1, 6.0: 1, 5.4: 1, nan: 1, nan: 1, 4.6: 1, 8.7: 2, 8.1: 1, 5.2: 1, 8.0: 2, 4.9: 1, 6.2: 2, 8.3: 1, 10.0: 1, 6.7: 1, 4.5: 1, 7.9: 1, 5.5: 1, 5.7: 1, 5.0: 1}

# %%
print("artists where titles are NA:")
print(title_data_dict['artist'])
# Out:
# artists where titles are NA:
# ...

# %%
print("authors where titles are NA:")
print(title_data_dict['author'])
# Out:
# authors where titles are NA:
# {'rob mitchum': 38, 'nick sylvester': 1, 'brad haywood': 1, 'zach baron': 1, 'jess harvell': 1, 'aaron leitko': 2, 'andrew gaerig': 1, 'nate patrin': 1, 'stuart berman': 1, 'joshua love': 1, 'matthew perpetua': 1, 'eric grandy': 2, 'brian howe': 1, 'ian cohen': 1, 'sheldon pearce': 1, 'marc masters': 1, 'philip sherburne': 1, 'jia tolentino': 1, 'zoe camp': 1}

# %%
print("pub_dates where titles are NA:")
print(title_data_dict['pub_date'])
# Out:
# pub_dates where titles are NA:
# {'3/5/02': 1, '2/20/06': 1, '11/24/02': 1, '7/25/04': 1, '3/18/03': 1, '9/25/02': 1, '8/23/04': 1, '1/7/02': 1, '10/22/02': 1, '10/9/03': 1, '3/31/02': 1, '1/22/03': 1, '10/14/02': 1, '2/10/02': 1, '5/23/04': 1, '2/12/02': 1, '2/19/03': 1, '4/26/06': 1, '1/21/03': 1, '6/25/02': 1, '4/30/03': 1, '3/6/03': 1, '5/27/02': 1, '5/8/05': 1, '4/27/03': 1, '6/21/04': 1, '6/9/06': 1, '11/17/06': 1, '11/28/06': 1, '1/24/07': 1, '3/1/07': 1, '3/8/07': 1, '4/27/07': 1, '5/7/07': 1, '6/12/07': 1, '7/9/07': 1, '8/23/07': 1, '1/9/08': 1, '2/25/08': 1, '10/1/08': 1, '9/15/09': 1, '3/12/10': 1, '4/14/10': 1, '5/19/10': 1, '6/3/10': 1, '7/8/10': 1, '10/6/10': 1, '3/23/11': 1, '4/27/11': 1, '5/23/11': 1, '10/18/11': 1, '5/31/12': 1, '2/12/14': 1, '4/13/15': 1, '10/21/15': 1, '4/1/16': 1, '6/24/16': 1, '6/10/16': 1}

# %%
print("titles where author types are NA:")
print(author_type_data_dict['title'])
# Out:
# titles where author types are NA:
# ...

# %%
print("scores where author types are NA:")
print(author_type_data_dict['score'])
# Out:
# scores where author types are NA:
# ...

# %%
print("artists where author types are NA:")
print(author_type_data_dict['artist'])
# Out:
# artists where author types are NA:
# ...

# %%
print("authors where author types are NA:")
print(author_type_data_dict['author'])
# Out:
# authors where author types are NA:
# ...

# %%
print("pub_dates where author types are NA:")
print(author_type_data_dict['pub_date'])
# Out:
# pub_dates where author types are NA:
# ...

# %%
#Task 2

# %%
import statsmodels.stats.multitest as multitest
import numpy as np
import matplotlib.pyplot as plt
from random import sample

# Creating a series of data of in range of 1-50.
x = np.linspace(1,50,50)
 
#Creating a Function.
def normal_dist(x , mean , sd):
    prob_density = (np.pi*sd) * np.exp(-0.5*((x-mean)/sd)**2)
    return prob_density
 
#Calculate mean and Standard deviation.
mean = 8
sd = 2
alpha = 0.05

random_sample1 = np.array(sample(list(x),30))
random_sample2 = np.array(sample(list(x),30))

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
stats.ttest_ind(random_sample1,random_sample2)
# Out:
# Ttest_indResult(statistic=0.025546857920770126, pvalue=0.9797064682222635)

# %%
def manyp_FP():
    #number of iterations to recieve a false positive
    pvals = []
    i = 0
    p = 0.5
    
    while p > 0.025:
        random_sample1 = np.random.normal(8,2,30)
        random_sample2 = np.random.normal(8,2,30)

        ttest = stats.ttest_ind(random_sample1,random_sample2)

        i += 1

        print('pval:')
        print(ttest[1])
        print('statistic:')
        print(ttest[0])

        pvals.append(ttest[1])
        
        p = ttest[1]
        
        multipletests = multitest.multipletests(pvals, alpha=0.05, is_sorted=False, returnsorted=True)
        
    
    return i


manyp_FP()
# Out:
# pval:
# 0.33128524345422483
# statistic:
# 0.9797366528091903
# pval:
# 0.7649985436218618
# statistic:
# 0.3003310099018944
# pval:
# 0.9227667704848846
# statistic:
# -0.09737189630555564
# pval:
# 0.7711910271646841
# statistic:
# 0.2921807736661947
# pval:
# 0.2760972814719305
# statistic:
# -1.0994899169320012
# pval:
# 0.9413371279698065
# statistic:
# -0.07390897418843073
# pval:
# 0.2329574628201263
# statistic:
# 1.205364361253849
# pval:
# 0.3082656670140189
# statistic:
# -1.0278977947820656
# pval:
# 0.5581850785077406
# statistic:
# 0.5889450067915587
# pval:
# 0.6259980403230054
# statistic:
# -0.4899776542434358
# pval:
# 0.9806162036990054
# statistic:
# 0.02440138525380944
# pval:
# 0.9514223463969251
# statistic:
# 0.06118485073011363
# pval:
# 0.4545435988401264
# statistic:
# -0.7529194313935784
# pval:
# 0.6367759477181851
# statistic:
# 0.4747104928739587
# pval:
# 0.945290874369388
# statistic:
# -0.06891935315738777
# pval:
# 0.5535984812926074
# statistic:
# ...

# %%
def manyp_FP_varyn(size):
    #number of iterations to recieve a false positive
    pvals = []
    i = 0
    p = 0.5
    
    while p > 0.025:
        random_sample1 = np.random.normal(8,2,size)
        random_sample2 = np.random.normal(8,2,size)

        ttest = stats.ttest_ind(random_sample1,random_sample2)

        i += 1

        pvals.append(ttest[1])
        
        p = ttest[1]
        
        multipletests = multitest.multipletests(pvals, alpha=0.05, is_sorted=False, returnsorted=True)
        
    
    return i


print('size 10: ' + str(manyp_FP_varyn(10)))
print('size 10: ' + str(manyp_FP_varyn(10)))
print('size 10: ' + str(manyp_FP_varyn(10)))
print('size 10: ' + str(manyp_FP_varyn(10)))
print('size 10: ' + str(manyp_FP_varyn(10)))

print()

print('size 50: ' + str(manyp_FP_varyn(50)))
print('size 50: ' + str(manyp_FP_varyn(50)))
print('size 50: ' + str(manyp_FP_varyn(50)))
print('size 50: ' + str(manyp_FP_varyn(50)))
print('size 50: ' + str(manyp_FP_varyn(50)))

print()

print('size 100: ' + str(manyp_FP_varyn(100)))
print('size 100: ' + str(manyp_FP_varyn(100)))
print('size 100: ' + str(manyp_FP_varyn(100)))
print('size 100: ' + str(manyp_FP_varyn(100)))
print('size 100: ' + str(manyp_FP_varyn(100)))
# Out:
# size 10: 75
# size 10: 94
# size 10: 11
# size 10: 22
# size 10: 16
#
# size 50: 55
# size 50: 4
# size 50: 6
# size 50: 88
# size 50: 1
#
# size 100: 52
# size 100: 68
# size 100: 32
# size 100: 55
# size 100: 44

# %%
#bonferroni
def manyp_FP_varyp_bonferroni(size):
    #number of iterations to recieve a false positive
    pvals = []
    i = 0
    p = 0.5
    
    while p > 0.025:
        random_sample1 = np.random.normal(8,2,size)
        random_sample2 = np.random.normal(8,2,size)

        ttest = stats.ttest_ind(random_sample1,random_sample2)

        i += 1

        pvals.append(ttest[1])
        
        p = ttest[1]
        
        multipletests = multitest.multipletests(pvals, alpha=0.05, method= 'bonferroni', is_sorted=False, returnsorted=True)
        
    
    return i


print('size 10 bonferroni: ' + str(manyp_FP_varyp_bonferroni(10)))
print('size 10 bonferroni: ' + str(manyp_FP_varyp_bonferroni(10)))
print('size 10 bonferroni: ' + str(manyp_FP_varyp_bonferroni(10)))
print('size 10 bonferroni: ' + str(manyp_FP_varyp_bonferroni(10)))
print('size 10 bonferroni: ' + str(manyp_FP_varyp_bonferroni(10)))

print()

print('size 50 bonferroni: ' + str(manyp_FP_varyp_bonferroni(50)))
print('size 50 bonferroni: ' + str(manyp_FP_varyp_bonferroni(50)))
print('size 50 bonferroni: ' + str(manyp_FP_varyp_bonferroni(50)))
print('size 50 bonferroni: ' + str(manyp_FP_varyp_bonferroni(50)))
print('size 50 bonferroni: ' + str(manyp_FP_varyp_bonferroni(50)))

print()

print('size 100 bonferroni: ' + str(manyp_FP_varyp_bonferroni(100)))
print('size 100 bonferroni: ' + str(manyp_FP_varyp_bonferroni(100)))
print('size 100 bonferroni: ' + str(manyp_FP_varyp_bonferroni(100)))
print('size 100 bonferroni: ' + str(manyp_FP_varyp_bonferroni(100)))
print('size 100 bonferroni: ' + str(manyp_FP_varyp_bonferroni(100)))
# Out:
# size 10 bonferroni: 61
# size 10 bonferroni: 31
# size 10 bonferroni: 5
# size 10 bonferroni: 25
# size 10 bonferroni: 123
#
# size 50 bonferroni: 30
# size 50 bonferroni: 32
# size 50 bonferroni: 8
# size 50 bonferroni: 17
# size 50 bonferroni: 14
#
# size 100 bonferroni: 45
# size 100 bonferroni: 36
# size 100 bonferroni: 136
# size 100 bonferroni: 29
# size 100 bonferroni: 14

# %%
#holm
def manyp_FP_varyp_holm(size):
    #number of iterations to recieve a false positive
    pvals = []
    i = 0
    p = 0.5
    
    while p > 0.025:
        random_sample1 = np.random.normal(8,2,size)
        random_sample2 = np.random.normal(8,2,size)

        ttest = stats.ttest_ind(random_sample1,random_sample2)

        i += 1

        pvals.append(ttest[1])
        
        p = ttest[1]
        
        multipletests = multitest.multipletests(pvals, alpha=0.05, method= 'holm', is_sorted=False, returnsorted=True)
        
    
    return i


print('size 10 holm: ' + str(manyp_FP_varyp_holm(10)))
print('size 10 holm: ' + str(manyp_FP_varyp_holm(10)))
print('size 10 holm: ' + str(manyp_FP_varyp_holm(10)))
print('size 10 holm: ' + str(manyp_FP_varyp_holm(10)))
print('size 10 holm: ' + str(manyp_FP_varyp_holm(10)))

print()

print('size 50 holm: ' + str(manyp_FP_varyp_holm(50)))
print('size 50 holm: ' + str(manyp_FP_varyp_holm(50)))
print('size 50 holm: ' + str(manyp_FP_varyp_holm(50)))
print('size 50 holm: ' + str(manyp_FP_varyp_holm(50)))
print('size 50 holm: ' + str(manyp_FP_varyp_holm(50)))

print()

print('size 100 holm: ' + str(manyp_FP_varyp_holm(100)))
print('size 100 holm: ' + str(manyp_FP_varyp_holm(100)))
print('size 100 holm: ' + str(manyp_FP_varyp_holm(100)))
print('size 100 holm: ' + str(manyp_FP_varyp_holm(100)))
print('size 100 holm: ' + str(manyp_FP_varyp_holm(100)))
# Out:
# size 10 holm: 34
# size 10 holm: 7
# size 10 holm: 41
# size 10 holm: 99
# size 10 holm: 71
#
# size 50 holm: 72
# size 50 holm: 3
# size 50 holm: 61
# size 50 holm: 6
# size 50 holm: 36
#
# size 100 holm: 15
# size 100 holm: 8
# size 100 holm: 14
# size 100 holm: 76
# size 100 holm: 68

# %%
#fdr_bh
def manyp_FP_varyp_fdr_bh(size):
    #number of iterations to recieve a false positive
    pvals = []
    i = 0
    p = 0.5
    
    while p > 0.025:
        random_sample1 = np.random.normal(8,2,size)
        random_sample2 = np.random.normal(8,2,size)

        ttest = stats.ttest_ind(random_sample1,random_sample2)

        i += 1

        pvals.append(ttest[1])
        
        p = ttest[1]
        
        multipletests = multitest.multipletests(pvals, alpha=0.05, method= 'fdr_bh', is_sorted=False, returnsorted=True)
        
    
    return i


print('size 10 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(10)))
print('size 10 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(10)))
print('size 10 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(10)))
print('size 10 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(10)))
print('size 10 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(10)))

print()

print('size 50 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(50)))
print('size 50 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(50)))
print('size 50 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(50)))
print('size 50 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(50)))
print('size 50 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(50)))

print()

print('size 100 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(100)))
print('size 100 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(100)))
print('size 100 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(100)))
print('size 100 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(100)))
print('size 100 fdr_bh: ' + str(manyp_FP_varyp_fdr_bh(100)))
# Out:
# size 10 fdr_bh: 55
# size 10 fdr_bh: 81
# size 10 fdr_bh: 4
# size 10 fdr_bh: 6
# size 10 fdr_bh: 19
#
# size 50 fdr_bh: 44
# size 50 fdr_bh: 51
# size 50 fdr_bh: 21
# size 50 fdr_bh: 36
# size 50 fdr_bh: 88
#
# size 100 fdr_bh: 40
# size 100 fdr_bh: 67
# size 100 fdr_bh: 19
# size 100 fdr_bh: 10
# size 100 fdr_bh: 100

# %%
#means 7

# %%
def manyp_FPnt(mean, standard_dev, size):
    #number of iterations to recieve a false positive
    pvals = []
    i = 0
    p = 0.5
    
    while p > 0.05:
        random_sample1 = np.random.normal(mean,standard_dev,size)
        random_sample2 = np.random.normal(mean,standard_dev,size)

        ttest = stats.ttest_ind(random_sample1,random_sample2)

        i += 1


        pvals.append(ttest[1])
        
        p = ttest[1]
        
        multipletests = multitest.multipletests(pvals, alpha=0.05, is_sorted=False, returnsorted=True)
        
    
    return i


print(manyp_FPnt(7, 1.5, 30))
print(manyp_FPnt(7, 1.5, 30))
print(manyp_FPnt(7, 1.5, 30))
print(manyp_FPnt(7, 1.5, 30))
print(manyp_FPnt(7, 1.5, 30))
print(manyp_FPnt(7, 1.5, 30))
# Out:
# 30
# 29
# 1
# 7
# 21
# 25

# %%
print(manyp_FPnt(9, 1.5, 30))
print(manyp_FPnt(9, 1.5, 30))
print(manyp_FPnt(9, 1.5, 30))
print(manyp_FPnt(9, 1.5, 30))
print(manyp_FPnt(9, 1.5, 30))
# Out:
# 77
# 24
# 31
# 59
# 15

# %%
#basic mean of 7, varying n size
print('size 10: ' + str(manyp_FPnt(7, 1.5, 10)))
print('size 10 : ' + str(manyp_FPnt(7, 1.5, 10)))
print('size 10 : ' + str(manyp_FPnt(7, 1.5, 10)))
print('size 10 : ' + str(manyp_FPnt(7, 1.5, 10)))
print('size 10 : ' + str(manyp_FPnt(7, 1.5, 10)))

print()

print('size 50 : ' + str(manyp_FPnt(7, 1.5, 50)))
print('size 50 : ' + str(manyp_FPnt(7, 1.5, 50)))
print('size 50 : ' + str(manyp_FPnt(7, 1.5, 50)))
print('size 50 : ' + str(manyp_FPnt(7, 1.5, 50)))
print('size 50 : ' + str(manyp_FPnt(7, 1.5, 50)))

print()

print('size 100 : ' + str(manyp_FPnt(7, 1.5, 100)))
print('size 100 : ' + str(manyp_FPnt(7, 1.5, 100)))
print('size 100 : ' + str(manyp_FPnt(7, 1.5, 100)))
print('size 100 : ' + str(manyp_FPnt(7, 1.5, 100)))
print('size 100 : ' + str(manyp_FPnt(7, 1.5, 100)))
# Out:
# size 10: 4
# size 10 : 3
# size 10 : 50
# size 10 : 17
# size 10 : 52
#
# size 50 : 4
# size 50 : 12
# size 50 : 31
# size 50 : 22
# size 50 : 5
#
# size 100 : 3
# size 100 : 6
# size 100 : 51
# size 100 : 6
# size 100 : 15

# %%
#basic mean of 9, varying n size
print('size 10: ' + str(manyp_FPnt(9, 1.5, 10)))
print('size 10 : ' + str(manyp_FPnt(9, 1.5, 10)))
print('size 10 : ' + str(manyp_FPnt(9, 1.5, 10)))
print('size 10 : ' + str(manyp_FPnt(9, 1.5, 10)))
print('size 10 : ' + str(manyp_FPnt(9, 1.5, 10)))

print()

print('size 50 : ' + str(manyp_FPnt(9, 1.5, 50)))
print('size 50 : ' + str(manyp_FPnt(9, 1.5, 50)))
print('size 50 : ' + str(manyp_FPnt(9, 1.5, 50)))
print('size 50 : ' + str(manyp_FPnt(9, 1.5, 50)))
print('size 50 : ' + str(manyp_FPnt(9, 1.5, 50)))

print()

print('size 100 : ' + str(manyp_FPnt(9, 1.5, 100)))
print('size 100 : ' + str(manyp_FPnt(9, 1.5, 100)))
print('size 100 : ' + str(manyp_FPnt(9, 1.5, 100)))
print('size 100 : ' + str(manyp_FPnt(9, 1.5, 100)))
print('size 100 : ' + str(manyp_FPnt(9, 1.5, 100)))
# Out:
# size 10: 5
# size 10 : 10
# size 10 : 7
# size 10 : 10
# size 10 : 33
#
# size 50 : 8
# size 50 : 31
# size 50 : 7
# size 50 : 4
# size 50 : 9
#
# size 100 : 17
# size 100 : 13
# size 100 : 7
# size 100 : 23
# size 100 : 11

# %%
def manyp_FP(mean, standard_dev, size, mtype):
    #number of iterations to recieve a false positive
    pvals = []
    i = 0
    p = 0.5
    
    while p > 0.05:
        random_sample1 = np.random.normal(mean,standard_dev,size)
        random_sample2 = np.random.normal(mean,standard_dev,size)

        ttest = stats.ttest_ind(random_sample1,random_sample2)

        i += 1


        pvals.append(ttest[1])
        
        p = ttest[1]
        
        multipletests = multitest.multipletests(pvals, alpha=0.05, method = mtype, is_sorted=False, returnsorted=True)
        
    
    return i

# %%
#basic mean of 7, varying n size, bonferroni
print('size 10: ' + str(manyp_FP(7, 1.5, 10, 'bonferroni')))
print('size 10 : ' + str(manyp_FP(7, 1.5, 10, 'bonferroni')))
print('size 10 : ' + str(manyp_FP(7, 1.5, 10, 'bonferroni')))
print('size 10 : ' + str(manyp_FP(7, 1.5, 10, 'bonferroni')))
print('size 10 : ' + str(manyp_FP(7, 1.5, 10, 'bonferroni')))

print()

print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'bonferroni')))
print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'bonferroni')))
print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'bonferroni')))
print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'bonferroni')))
print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'bonferroni')))

print()

print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'bonferroni')))
print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'bonferroni')))
print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'bonferroni')))
print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'bonferroni')))
print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'bonferroni')))
# Out:
# size 10: 5
# size 10 : 19
# size 10 : 28
# size 10 : 26
# size 10 : 4
#
# size 50 : 12
# size 50 : 14
# size 50 : 12
# size 50 : 4
# size 50 : 11
#
# size 100 : 28
# size 100 : 6
# size 100 : 43
# size 100 : 1
# size 100 : 10

# %%
#basic mean of 7, varying n size, bonferroni
print('size 10: ' + str(manyp_FP(9, 1.5, 10, 'bonferroni')))
print('size 10 : ' + str(manyp_FP(9, 1.5, 10, 'bonferroni')))
print('size 10 : ' + str(manyp_FP(9, 1.5, 10, 'bonferroni')))
print('size 10 : ' + str(manyp_FP(9, 1.5, 10, 'bonferroni')))
print('size 10 : ' + str(manyp_FP(9, 1.5, 10, 'bonferroni')))

print()

print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'bonferroni')))
print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'bonferroni')))
print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'bonferroni')))
print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'bonferroni')))
print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'bonferroni')))

print()

print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'bonferroni')))
print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'bonferroni')))
print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'bonferroni')))
print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'bonferroni')))
print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'bonferroni')))
# Out:
# size 10: 10
# size 10 : 34
# size 10 : 8
# size 10 : 16
# size 10 : 10
#
# size 50 : 3
# size 50 : 5
# size 50 : 17
# size 50 : 22
# size 50 : 2
#
# size 100 : 11
# size 100 : 53
# size 100 : 45
# size 100 : 25
# size 100 : 80

# %%
#basic mean of 7, varying n size, holm
print('size 10: ' + str(manyp_FP(7, 1.5, 10, 'holm')))
print('size 10 : ' + str(manyp_FP(7, 1.5, 10, 'holm')))
print('size 10 : ' + str(manyp_FP(7, 1.5, 10, 'holm')))
print('size 10 : ' + str(manyp_FP(7, 1.5, 10, 'holm')))
print('size 10 : ' + str(manyp_FP(7, 1.5, 10, 'holm')))

print()

print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'holm')))
print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'holm')))
print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'holm')))
print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'holm')))
print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'holm')))

print()

print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'holm')))
print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'holm')))
print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'holm')))
print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'holm')))
print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'holm')))
# Out:
# size 10: 1
# size 10 : 40
# size 10 : 30
# size 10 : 7
# size 10 : 18
#
# size 50 : 6
# size 50 : 8
# size 50 : 218
# size 50 : 6
# size 50 : 18
#
# size 100 : 9
# size 100 : 2
# size 100 : 13
# size 100 : 11
# size 100 : 35

# %%
#basic mean of 9, varying n size, holm
print('size 10: ' + str(manyp_FP(9, 1.5, 10, 'holm')))
print('size 10 : ' + str(manyp_FP(9, 1.5, 10, 'holm')))
print('size 10 : ' + str(manyp_FP(9, 1.5, 10, 'holm')))
print('size 10 : ' + str(manyp_FP(9, 1.5, 10, 'holm')))
print('size 10 : ' + str(manyp_FP(9, 1.5, 10, 'holm')))

print()

print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'holm')))
print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'holm')))
print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'holm')))
print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'holm')))
print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'holm')))

print()

print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'holm')))
print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'holm')))
print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'holm')))
print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'holm')))
print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'holm')))
# Out:
# size 10: 4
# size 10 : 16
# size 10 : 40
# size 10 : 16
# size 10 : 19
#
# size 50 : 39
# size 50 : 61
# size 50 : 4
# size 50 : 11
# size 50 : 13
#
# size 100 : 32
# size 100 : 6
# size 100 : 17
# size 100 : 17
# size 100 : 44

# %%
#basic mean of 7, varying n size, fdr_bh
print('size 10: ' + str(manyp_FP(7, 1.5, 10, 'fdr_bh')))
print('size 10 : ' + str(manyp_FP(7, 1.5, 10, 'fdr_bh')))
print('size 10 : ' + str(manyp_FP(7, 1.5, 10, 'fdr_bh')))
print('size 10 : ' + str(manyp_FP(7, 1.5, 10, 'fdr_bh')))
print('size 10 : ' + str(manyp_FP(7, 1.5, 10, 'fdr_bh')))

print()

print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'fdr_bh')))
print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'fdr_bh')))
print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'fdr_bh')))
print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'fdr_bh')))
print('size 50 : ' + str(manyp_FP(7, 1.5, 50, 'fdr_bh')))

print()

print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'fdr_bh')))
print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'fdr_bh')))
print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'fdr_bh')))
print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'fdr_bh')))
print('size 100 : ' + str(manyp_FP(7, 1.5, 100, 'fdr_bh')))
# Out:
# size 10: 3
# size 10 : 4
# size 10 : 30
# size 10 : 8
# size 10 : 16
#
# size 50 : 18
# size 50 : 14
# size 50 : 22
# size 50 : 5
# size 50 : 3
#
# size 100 : 30
# size 100 : 8
# size 100 : 35
# size 100 : 5
# size 100 : 2

# %%
#basic mean of 9, varying n size, fdr_bh
print('size 10: ' + str(manyp_FP(9, 1.5, 10, 'fdr_bh')))
print('size 10 : ' + str(manyp_FP(9, 1.5, 10, 'fdr_bh')))
print('size 10 : ' + str(manyp_FP(9, 1.5, 10, 'fdr_bh')))
print('size 10 : ' + str(manyp_FP(9, 1.5, 10, 'fdr_bh')))
print('size 10 : ' + str(manyp_FP(9, 1.5, 10, 'fdr_bh')))

print()

print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'fdr_bh')))
print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'fdr_bh')))
print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'fdr_bh')))
print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'fdr_bh')))
print('size 50 : ' + str(manyp_FP(9, 1.5, 50, 'fdr_bh')))

print()

print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'fdr_bh')))
print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'fdr_bh')))
print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'fdr_bh')))
print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'fdr_bh')))
print('size 100 : ' + str(manyp_FP(9, 1.5, 100, 'fdr_bh')))
# Out:
# size 10: 25
# size 10 : 7
# size 10 : 7
# size 10 : 27
# size 10 : 7
#
# size 50 : 76
# size 50 : 75
# size 50 : 35
# size 50 : 30
# size 50 : 20
#
# size 100 : 68
# size 100 : 3
# size 100 : 44
# size 100 : 15
# size 100 : 32
